# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewpark19/4thyear-FYP/blob/main/standard_cnn_multi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Jun  6 01:24:13 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.17.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.2 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.17.0

# %%
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import matplotlib.pyplot as plt
from tensorflow.keras import layers
import tensorflow_addons as tfa

# %%
# !unzip /content/drive/MyDrive/melanoma_data/isic_2020/train_2020/train_2020.zip > /dev/null
# !unzip /content/drive/MyDrive/melanoma_data/isic_2020/test_2020/test_2020.zip > /dev/null
# !unzip /content/drive/MyDrive/melanoma_data/isic_2019/train_2019/train_2019.zip > /dev/null

# %%
from sklearn.model_selection import train_test_split

train2020_dir = '/content/train_2020'
test2020_dir = '/content/test_2020'
train2019_dir = '/content/train_2019' 
data_dir = '/content/drive/MyDrive/melanoma_data'

def get_df(data_dir, train2020_dir, test2020_dir, train2019_dir, use_meta=False):

    ###Training Data
    #2020 Data
    df_train = pd.read_csv(os.path.join(data_dir, r'isic_2020','train_2020.csv')) #path to train_2020.csv
    df_train['filepath'] = df_train['image_name'].apply(lambda x: os.path.join(train2020_dir, f'{x}.jpg'))

    # #2019 data
    df_train2 = pd.read_csv(os.path.join(data_dir, r'isic_2019', 'train_2019.csv')) #path to train_2019.csv
    df_train2['filepath'] = df_train2['image_name'].apply(lambda x: os.path.join(train2019_dir, f'{x}.jpg'))

    # #Change Labels to match
    df_train['diagnosis']  = df_train['diagnosis'].apply(lambda x: x.replace('seborrheic keratosis', 'BKL'))
    df_train['diagnosis']  = df_train['diagnosis'].apply(lambda x: x.replace('lichenoid keratosis', 'BKL'))
    df_train['diagnosis']  = df_train['diagnosis'].apply(lambda x: x.replace('solar lentigo', 'BKL'))
    df_train['diagnosis']  = df_train['diagnosis'].apply(lambda x: x.replace('lentigo NOS', 'BKL'))
    df_train['diagnosis']  = df_train['diagnosis'].apply(lambda x: x.replace('cafe-au-lait macule', 'unknown'))
    df_train['diagnosis']  = df_train['diagnosis'].apply(lambda x: x.replace('atypical melanocytic proliferation', 'unknown'))

    df_train2['diagnosis'] = df_train2['diagnosis'].apply(lambda x: x.replace('NV', 'nevus'))
    df_train2['diagnosis'] = df_train2['diagnosis'].apply(lambda x: x.replace('MEL', 'melanoma'))

    df_train = pd.concat([df_train, df_train2]).reset_index(drop=True)

    # ###Test Data
    df_test = pd.read_csv(os.path.join(data_dir,r'isic_2020', 'test_2020.csv'))
    df_test['filepath'] = df_test['image_name'].apply(lambda x: os.path.join(test2020_dir, f'{x}.jpg'))

    if use_meta:
        df_train, df_test, meta_features, n_meta_features = get_meta_data(df_train, df_test)
    else:
        meta_features = None
        n_meta_features = 0

    diagnosis2idx = {d: idx for idx, d in enumerate(sorted(df_train.diagnosis.unique()))}
    df_train['target'] = df_train['diagnosis'].map(diagnosis2idx)
    mel_idx = diagnosis2idx['melanoma']

    df_train, df_val = train_test_split(df_train, test_size=0.25, stratify = df_train[['diagnosis']])

    return df_train, df_val, df_test, meta_features, n_meta_features, mel_idx
  

df_train, df_val, df_test, _, _, mel_idx = get_df(data_dir, train2020_dir, test2020_dir, train2019_dir, use_meta=False)

# %%
SEED = 42

num_classes = 9
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 64
patience= 30
num_epochs = 100

image_size= 224

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(horizontal_flip=True,
                                   vertical_flip=False,
                                   rescale=1/255.0,
                                  #  rotation_range = 90,
                                  #  brightness_range=[0.2,1.0],
                                  #  zoom_range=[0.5,1.0],
                                  #preprocessing_function=keras.applications.resnet50.preprocess_input
                                   )

train_generator = train_datagen.flow_from_dataframe(     
    dataframe=df_train,  
    directory=None,
    x_col='filepath', # name of col in data frame that contains file names
    y_col="diagnosis", # name of col with labels 
    batch_size=batch_size,
    shuffle=True,
    #save_to_dir=saveDir,
    target_size=(image_size, image_size),
    color_mode='rgb',
    class_mode='sparse'
)

valid_generator = train_datagen.flow_from_dataframe(     
    dataframe=df_val,  
    directory=None,
    x_col='filepath', # name of col in data frame that contains file names
    y_col="diagnosis", # name of col with labels 
    batch_size=batch_size,
    shuffle=True,
    #save_to_dir=saveDir,
    target_size=(image_size, image_size),
    color_mode='rgb',
    class_mode='sparse'
)


# imgs,labels = next(train_generator)
# print(f"imgs.shape:{imgs.shape},labels.shape:{labels.shape}")

# X_train, X_val, y_train, y_val = train_test_split(imgs,labels, test_size=0.25,stratify=labels, random_state=SEED)
# print(f"X_train.shape:{X_train.shape},X_val.shape:{X_val.shape}")
# print(f"y_train.shape:{y_train.shape},y_val.shape:{y_val.shape}")
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/dataframe_iterator.py:282: UserWarning: Found 11661 invalid image filename(s) in x_col="filepath". These filename(s) will be ignored.
#   .format(n_invalid, x_col)
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/dataframe_iterator.py:282: UserWarning: Found 3799 invalid image filename(s) in x_col="filepath". These filename(s) will be ignored.
#   .format(n_invalid, x_col)
# Found 32181 validated image filenames belonging to 9 classes.
# Found 10816 validated image filenames belonging to 9 classes.

# %%
from sklearn.utils import class_weight

weights = class_weight.compute_class_weight(class_weight = 'balanced',
                                            classes = np.unique(train_generator.classes),
                                            y= train_generator.classes)
weights = dict(zip(np.unique(train_generator.classes), weights))

model_name = "melanoma_ResNet50.h5"
log_dir = os.path.join(os.getcwd(), 'logs')
filepath='ResNet50.{epoch:02d}-{val_loss:.4f}.h5'
ck_path = os.path.join(log_dir, filepath)
if not os.path.isdir(log_dir):
  os.makedirs(log_dir)
mc = keras.callbacks.ModelCheckpoint(ck_path, monitor='val_loss',save_best_only=True,save_weights_only=True)
es = keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, verbose=0) # when patience epoch val_loss not improve, stop train
# tb = keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=0)
callbacks = [es, mc]

# %%
from keras import regularizers
import seaborn as sns
# %matplotlib inline
import seaborn as sns
from tensorflow.keras.layers import Flatten,Dense,Dropout,BatchNormalization,Conv2D,MaxPooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.metrics import Recall
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau
from sklearn.metrics import classification_report,confusion_matrix

# %%
input_shape=(image_size,image_size,3)

model=Sequential()


model.add(Conv2D(64,(3,3),input_shape=(image_size,image_size,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())


model.add(Conv2D(512,(3,3),input_shape=(image_size,image_size,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))



model.add(Dropout(0.3))

model.add(Conv2D(1024,(3,3),input_shape=(image_size,image_size,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())


model.add(Dropout(0.4))

model.add(Conv2D(1024,(1,1),input_shape=(image_size,image_size,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(1, 1)))



model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(256,activation='relu',kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.5))


model.add(Dense(9,activation='softmax'))

model.compile(
    optimizer='adam',
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits = False),
    metrics=[
        keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
        keras.metrics.SparseTopKCategoricalAccuracy(3, name="top-3-accuracy"),
    ],
)
model.summary()

history = model.fit(train_generator, 
                     batch_size = batch_size,
                     epochs=num_epochs,
                     use_multiprocessing=True,
                     validation_data = valid_generator,
                     callbacks=callbacks, 
                     #class_weight = weights, 
                     workers=6)

model.save('standard_multi_final.h5') 
shutil.copy('standard_multi_final.h5', '/content/drive/MyDrive/melanoma_data/models')


plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 64)     0
#  )
#
#  batch_normalization (BatchN  (None, 111, 111, 64)     256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 512)     295424
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 512)      0
#  2D)
#
#  dropout (Dropout)           (None, 54, 54, 512)       0
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 1024)      4719616
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 1024)     0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 26, 26, 1024)     4096
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 26, 26, 1024)      0
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 1024)      1049600
#
#  max_pooling2d_3 (MaxPooling  (None, 26, 26, 1024)     0
#  2D)
#
#  dropout_2 (Dropout)         (None, 26, 26, 1024)      0
#
#  flatten (Flatten)           (None, 692224)            0
#
#  dense (Dense)               (None, 256)               177209600
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 183,282,697
# Trainable params: 183,280,521
# Non-trainable params: 2,176
# _________________________________________________________________
# Epoch 1/100
# 503/503 [==============================] - 372s 700ms/step - loss: 15.4838 - accuracy: 0.4434 - top-3-accuracy: 0.8420 - val_loss: 2.6264 - val_accuracy: 0.5720 - val_top-3-accuracy: 0.8438
# Epoch 2/100
# 503/503 [==============================] - 325s 640ms/step - loss: 2.4259 - accuracy: 0.5668 - top-3-accuracy: 0.8482 - val_loss: 2.1218 - val_accuracy: 0.6613 - val_top-3-accuracy: 0.8529
# Epoch 3/100
# 503/503 [==============================] - 351s 693ms/step - loss: 1.6948 - accuracy: 0.6455 - top-3-accuracy: 0.8612 - val_loss: 1.5517 - val_accuracy: 0.6749 - val_top-3-accuracy: 0.8745
# Epoch 4/100
# 503/503 [==============================] - 324s 639ms/step - loss: 1.4889 - accuracy: 0.6549 - top-3-accuracy: 0.8717 - val_loss: 1.3608 - val_accuracy: 0.6756 - val_top-3-accuracy: 0.8772
# Epoch 5/100
# 503/503 [==============================] - 326s 643ms/step - loss: 1.4248 - accuracy: 0.6667 - top-3-accuracy: 0.8828 - val_loss: 1.2721 - val_accuracy: 0.6860 - val_top-3-accuracy: 0.8920
# Epoch 6/100
# 503/503 [==============================] - 321s 632ms/step - loss: 1.3631 - accuracy: 0.6748 - top-3-accuracy: 0.8889 - val_loss: 1.2975 - val_accuracy: 0.6894 - val_top-3-accuracy: 0.8942
# Epoch 7/100
# 503/503 [==============================] - 343s 676ms/step - loss: 1.2931 - accuracy: 0.6772 - top-3-accuracy: 0.8912 - val_loss: 1.5664 - val_accuracy: 0.6032 - val_top-3-accuracy: 0.8779
# Epoch 8/100
# 503/503 [==============================] - 346s 682ms/step - loss: 1.2468 - accuracy: 0.6813 - top-3-accuracy: 0.8954 - val_loss: 1.1026 - val_accuracy: 0.7060 - val_top-3-accuracy: 0.8944
# Epoch 9/100
# 503/503 [==============================] - 314s 620ms/step - loss: 1.2043 - accuracy: 0.6869 - top-3-accuracy: 0.8979 - val_loss: 1.1549 - val_accuracy: 0.6897 - val_top-3-accuracy: 0.8933
# Epoch 10/100
# 503/503 [==============================] - 315s 622ms/step - loss: 1.2759 - accuracy: 0.6947 - top-3-accuracy: 0.9012 - val_loss: 1.3731 - val_accuracy: 0.6598 - val_top-3-accuracy: 0.8946
# Epoch 11/100
# 503/503 [==============================] - 317s 621ms/step - loss: 1.2635 - accuracy: 0.7022 - top-3-accuracy: 0.9056 - val_loss: 2.0901 - val_accuracy: 0.5563 - val_top-3-accuracy: 0.8783
# Epoch 12/100
# 503/503 [==============================] - 315s 621ms/step - loss: 1.2676 - accuracy: 0.7097 - top-3-accuracy: 0.9077 - val_loss: 1.3523 - val_accuracy: 0.6732 - val_top-3-accuracy: 0.9088
# Epoch 13/100
# 503/503 [==============================] - 316s 622ms/step - loss: 1.3074 - accuracy: 0.7105 - top-3-accuracy: 0.9076 - val_loss: 1.5466 - val_accuracy: 0.6463 - val_top-3-accuracy: 0.8815
# Epoch 14/100
# 503/503 [==============================] - 319s 628ms/step - loss: 1.2031 - accuracy: 0.7139 - top-3-accuracy: 0.9085 - val_loss: 1.3979 - val_accuracy: 0.6731 - val_top-3-accuracy: 0.8961
# Epoch 15/100
# 503/503 [==============================] - 320s 631ms/step - loss: 1.2551 - accuracy: 0.7217 - top-3-accuracy: 0.9115 - val_loss: 1.4447 - val_accuracy: 0.6280 - val_top-3-accuracy: 0.8852
# Epoch 16/100
# 503/503 [==============================] - 321s 632ms/step - loss: 1.2516 - accuracy: 0.7203 - top-3-accuracy: 0.9132 - val_loss: 1.2888 - val_accuracy: 0.7081 - val_top-3-accuracy: 0.9079
# Epoch 17/100
# 503/503 [==============================] - 323s 637ms/step - loss: 1.2593 - accuracy: 0.7219 - top-3-accuracy: 0.9126 - val_loss: 1.2077 - val_accuracy: 0.7139 - val_top-3-accuracy: 0.9013
# Epoch 18/100
# 503/503 [==============================] - 346s 682ms/step - loss: 1.1972 - accuracy: 0.7275 - top-3-accuracy: 0.9147 - val_loss: 1.6527 - val_accuracy: 0.5641 - val_top-3-accuracy: 0.8871
# Epoch 19/100
# 503/503 [==============================] - 318s 627ms/step - loss: 1.1857 - accuracy: 0.7286 - top-3-accuracy: 0.9153 - val_loss: 1.3080 - val_accuracy: 0.6849 - val_top-3-accuracy: 0.8902
# Epoch 20/100
# 503/503 [==============================] - 318s 626ms/step - loss: 1.2167 - accuracy: 0.7305 - top-3-accuracy: 0.9161 - val_loss: 1.2364 - val_accuracy: 0.7348 - val_top-3-accuracy: 0.9244
# Epoch 21/100
# 503/503 [==============================] - 344s 680ms/step - loss: 1.2604 - accuracy: 0.7331 - top-3-accuracy: 0.9179 - val_loss: 1.2818 - val_accuracy: 0.7137 - val_top-3-accuracy: 0.9124
# Epoch 22/100
# 503/503 [==============================] - 324s 638ms/step - loss: 1.2133 - accuracy: 0.7363 - top-3-accuracy: 0.9179 - val_loss: 1.4265 - val_accuracy: 0.6940 - val_top-3-accuracy: 0.9050
# Epoch 23/100
# 503/503 [==============================] - 334s 658ms/step - loss: 1.1933 - accuracy: 0.7341 - top-3-accuracy: 0.9191 - val_loss: 1.2581 - val_accuracy: 0.7040 - val_top-3-accuracy: 0.9088
# Epoch 24/100
# 503/503 [==============================] - 355s 699ms/step - loss: 1.1753 - accuracy: 0.7360 - top-3-accuracy: 0.9221 - val_loss: 1.5888 - val_accuracy: 0.5800 - val_top-3-accuracy: 0.8641
# Epoch 25/100
# 503/503 [==============================] - 411s 812ms/step - loss: 1.2404 - accuracy: 0.7370 - top-3-accuracy: 0.9191 - val_loss: 1.3211 - val_accuracy: 0.6915 - val_top-3-accuracy: 0.9125
# Epoch 26/100
# 503/503 [==============================] - 368s 722ms/step - loss: 1.2588 - accuracy: 0.7390 - top-3-accuracy: 0.9219 - val_loss: 1.7422 - val_accuracy: 0.6199 - val_top-3-accuracy: 0.8701
# Epoch 27/100
# 503/503 [==============================] - 310s 612ms/step - loss: 1.1797 - accuracy: 0.7407 - top-3-accuracy: 0.9232 - val_loss: 1.2538 - val_accuracy: 0.7246 - val_top-3-accuracy: 0.9195
# Epoch 28/100
# 503/503 [==============================] - 312s 615ms/step - loss: 1.2067 - accuracy: 0.7409 - top-3-accuracy: 0.9217 - val_loss: 3.3091 - val_accuracy: 0.3766 - val_top-3-accuracy: 0.6271
# Epoch 29/100
# 503/503 [==============================] - 311s 614ms/step - loss: 1.1853 - accuracy: 0.7414 - top-3-accuracy: 0.9239 - val_loss: 1.2461 - val_accuracy: 0.7358 - val_top-3-accuracy: 0.9215
# Epoch 30/100
# 503/503 [==============================] - 312s 615ms/step - loss: 1.2354 - accuracy: 0.7430 - top-3-accuracy: 0.9229 - val_loss: 1.3271 - val_accuracy: 0.7143 - val_top-3-accuracy: 0.9121
# Epoch 31/100
# 503/503 [==============================] - 315s 622ms/step - loss: 1.2436 - accuracy: 0.7464 - top-3-accuracy: 0.9256 - val_loss: 1.3248 - val_accuracy: 0.7260 - val_top-3-accuracy: 0.9262
# Epoch 32/100
# 503/503 [==============================] - 342s 674ms/step - loss: 1.2022 - accuracy: 0.7448 - top-3-accuracy: 0.9257 - val_loss: 4.0804 - val_accuracy: 0.3314 - val_top-3-accuracy: 0.5797
# Epoch 33/100
# 503/503 [==============================] - 318s 627ms/step - loss: 1.2090 - accuracy: 0.7466 - top-3-accuracy: 0.9230 - val_loss: 1.5501 - val_accuracy: 0.6363 - val_top-3-accuracy: 0.8843
# Epoch 34/100
# 503/503 [==============================] - 316s 623ms/step - loss: 1.2042 - accuracy: 0.7458 - top-3-accuracy: 0.9244 - val_loss: 1.1824 - val_accuracy: 0.7340 - val_top-3-accuracy: 0.9273
# Epoch 35/100
# 503/503 [==============================] - 344s 679ms/step - loss: 1.2260 - accuracy: 0.7485 - top-3-accuracy: 0.9250 - val_loss: 1.4313 - val_accuracy: 0.7126 - val_top-3-accuracy: 0.9066
# Epoch 36/100
# 503/503 [==============================] - 325s 641ms/step - loss: 1.2401 - accuracy: 0.7484 - top-3-accuracy: 0.9268 - val_loss: 1.9020 - val_accuracy: 0.5056 - val_top-3-accuracy: 0.8342
# Epoch 37/100
# 503/503 [==============================] - 332s 654ms/step - loss: 1.1891 - accuracy: 0.7485 - top-3-accuracy: 0.9263 - val_loss: 1.2370 - val_accuracy: 0.7278 - val_top-3-accuracy: 0.9269
# Epoch 38/100
# 503/503 [==============================] - 356s 701ms/step - loss: 1.2453 - accuracy: 0.7503 - top-3-accuracy: 0.9286 - val_loss: 2.6721 - val_accuracy: 0.4480 - val_top-3-accuracy: 0.8445

# %%
from sklearn.metrics import precision_recall_curve, auc, average_precision_score, roc_auc_score
from sklearn.preprocessing import LabelBinarizer


ypred = model.predict(valid_generator)
ypred = ypred.argmax(axis=-1)

target= ['AK', 'BCC', 'BKL', 'DF', 'SCC',
          'VASC', 'melanoma', 'nevus', 'unknown']

# set plot figure size
fig, c_ax = plt.subplots(1,1, figsize = (12, 8))

def multiclass_pr(valid_generator, ypred):
  lb = LabelBinarizer()
  lb.fit(valid_generator.labels)
  y_test = lb.transform(valid_generator.labels)
  ypred = lb.transform(ypred)

  for idx, c_label in enumerate(target):
    precision, recall, _  = precision_recall_curve(y_test[:,idx].astype(int), ypred[:,idx].astype(int))
    c_ax.plot(recall, precision, label = '%s (AUC:%0.2f)'  % (c_label, auc(recall, precision)))

  #c_ax.plot(recall, precision, 'b-', label = 'Random Guessing')
  print('ROC:', roc_auc_score(valid_generator.labels, ypred, multi_class="ovo"))
  return average_precision_score(y_test, ypred, average = 'micro')


print('Average Precision score:', multiclass_pr(valid_generator, ypred))

c_ax.legend()
c_ax.set_xlabel('Recall')
c_ax.set_ylabel('Precision')
plt.show()
# Out:
# ROC: 0.49959167740045285
# Average Precision score: 0.1898066834107991
